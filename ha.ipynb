# %%
# !pip install ultralytics -q

# %%
from ultralytics import YOLO

# %%
# !yolo segment predict model="yolov8l-seg.pt" source="1080p_240.mp4" save=True

# %%
# !yolo train model=yolov8n.pt data=coco128.yaml epochs=3 imgsz=640  device="mps"
# Out:
# WARNING ⚠️ Ultralytics settings reset to defaults. This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# View and update settings with 'yolo settings' or at '/Users/game/Library/Application Support/Ultralytics/settings.yaml'
# /Users/game/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional_pil.py:242: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   interpolation: int = Image.BILINEAR,
# /Users/game/opt/anaconda3/lib/python3.9/site-packages/torchvision/transforms/functional_pil.py:286: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   interpolation: int = Image.NEAREST,
# ...
